# %%
import firebase_admin
from firebase_admin import credentials

# %%
cred = credentials.Certificate("/Users/jkn/Documents/Projects/university/illarek-lab/platform-api/credentials_FMC/layout_example-firebase-adminsdk.json")
firebase_admin.initialize_app(cred)

# %%
from firebase_admin import messaging

message = messaging.Message(
    notification=messaging.Notification(
        title="Hola",
        body="Tienes un nuevo mensaje",
    ),
    token="TOKEN_DEL_DISPOSITIVO",
)

response = messaging.send(message)
print("Mensaje enviado:", response)
# Out:
# /var/folders/8z/_xyp4wvj3tq4p24ty09mxxp80000gn/T/ipykernel_97092/3595020665.py:3: DeprecationWarning: Message.token is deprecated. Use Message.fid instead.
#   message = messaging.Message(
# Mensaje enviado: projects/illarek-8bd2f/messages/0:1783479782117018%9fce0b219fce0b21

# %%
from firebase_admin import messaging

message = messaging.Message(
    notification=messaging.Notification(
        title="Hola",
        body="Hola Team",
    ),
    token="fAX0jm_tQwSzkt2dZmhLkU:APA91bGki3CUD0ZxcytUq-cI4OIDAgAJotmjUHwWeonPV1iNu2hINYJfSaxjq5aDYe_DCraXxlr9TPGeqMv6avgkIS6NnpID1bu7o6yjtCaI5UoW-lAXqog",
)

response = messaging.send(message)
print("Mensaje enviado:", response)
# Out:
# /var/folders/8z/_xyp4wvj3tq4p24ty09mxxp80000gn/T/ipykernel_50605/2693740581.py:3: DeprecationWarning: Message.token is deprecated. Use Message.fid instead.
#   message = messaging.Message(
# Mensaje enviado: projects/illarek-8bd2f/messages/0:1783554745554262%9fce0b219fce0b21

# %%
from firebase_admin import messaging

message = messaging.Message(
    notification=messaging.Notification(
        title="Hola",
        body="Test 2 de notificación a todos los usuarios",
    ),
    topic="all_users",
)

response = messaging.send(message)

print("Mensaje enviado:", response)
# Out:
# Mensaje enviado: projects/illarek-8bd2f/messages/8135829252544637736
