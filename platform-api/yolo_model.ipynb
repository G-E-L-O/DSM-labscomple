# %%
! uv pip install ultralytics
! yolo export model=yolov8n.pt format=tflite imgsz=320 int8=False half=True
# Out:
# zsh:1: command not found: pip
# zsh:1: command not found: yolo

# %%
uv add litert-torch ai-edge-litert
uv run yolo export model=yolov8n.pt format=litert imgsz=320

# %%
! uv add litert-torch ai-edge-litert
# Out:
# Resolved 217 packages in 100ms
# ⠙ ai-edge-tensorflow==2.21.0.dev20251110                                        error: Distribution `ai-edge-litert==2.1.2 @ registry+https://pypi.org/simple` can't be installed because it doesn't have a source distribution or wheel for the current platform
#
# hint: You're using CPython 3.14 (`cp314`), but `ai-edge-litert` (v2.1.2) only has wheels with the following Python ABI tags: `cp312`, `cp313`

# %%
! mkdir ~/yolo-export && cd ~/yolo-export
! uv init --python 3.12
! uv add ultralytics litert-torch ai-edge-litert
! uv run yolo export model=yolov8n.pt format=litert imgsz=320
# Out:
# error: Project is already initialized in `/Users/jkn/Documents/Projects/university/illarek-lab/platform-api` (`pyproject.toml` file exists)
# Resolved 217 packages in 177ms
# ⠙ ai-edge-tensorflow==2.21.0.dev20251110                                        error: Distribution `ai-edge-litert==2.1.2 @ registry+https://pypi.org/simple` can't be installed because it doesn't have a source distribution or wheel for the current platform
#
# hint: You're using CPython 3.14 (`cp314`), but `ai-edge-litert` (v2.1.2) only has wheels with the following Python ABI tags: `cp312`, `cp313`
#    Building platform-api @ file:///Users/jkn/Documents/Projects/university/illar
#    Building platform-api @ file:///Users/jkn/Documents/Projects/university/illar
#    Building platform-api @ file:///Users/jkn/Documents/Projects/university/illar
#       Built platform-api @ file:///Users/jkn/Documents/Projects/university/illar
# Uninstalled 1 package in 0.98ms
# ...
